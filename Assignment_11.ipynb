# %%
1. Create an assert statement that throws an AssertionError if the variable spam is a negative integer.
Answer:
spam = int(input())
assert spam > 0, "Spam value is negative intger"

2. Write an assert statement that triggers an AssertionError if the variables eggs and bacon contain strings that are the same as each other, even if their cases are different (that is, 'hello' and 'hello' are considered the same, and 'goodbye' and 'GOODbye' are also considered the same).
Answer:
eggs = str(input())
bacon = str(input())
eggs = eggs.lower()
bacon = bacon.lower()
assert eggs != bacon , "The strings eggs and bacon are same"
print(" The string", eggs, " and ", bacon, "are not same"
      
3. Create an assert statement that throws an AssertionError every time.
Answer:
assert False, "whenever executed throws assertion error"

4. What are the two lines that must be present in your software in order to call logging.debug()?
Answer:
import logging
logging.basicConfig(
    filename='test.log',
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

      
5. What are the two lines that your program must have in order to have logging.debug() send a logging message to a file named programLog.txt?
Answer:
import logging
logging.basicConfig(
    filename='test.log',
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

6. What are the five levels of logging?
Answer: Below are the levels of logging:
      logging.INFO
      logging.DEBUG
      loggging.WARNING
      logging.ERROR
      logging.CRITICAL
      
7. What line of code would you add to your software to disable all logging messages?
Answer: logging.disable(logging.CRITICAL)
      
8.Why is using logging messages better than using print() to display the same message?
Answer: With logging module it is to display and hide messages with simple logging.disable command.
      also logging is for programmer to debug code and print is used to display a message to user.
      
9. What are the differences between the Step Over, Step In, and Step Out buttons in the debugger?
Answer: Step In- one line execution at a time
Step Over - excecute the next line of code, but if it is a program, it will
        complete the entire function call.
Step out  - execute the lines of code unti it returns from the current function.
        (out is useful when you stepped into a function call).
      
10.After you click Continue, when will the debugger stop ?
Answer: clicked continue, the debugger will stop when it has reached the end of the program or a line with a breakpoint.

11. What is the concept of a breakpoint?
Answer: A breakpoint can be a specific line of code and which forces the debugger to
pause whenever the program execution reaches that line.
